# %%
from gdb2csv import converter
from gdbList import list_layers_with_types
import pandas as pd
import geopandas as gpd

# %%
# List all layers within GDB by calling "list_layers_with_types" function
list_layers_with_types(gdb_path)
# Out:
# Layers in the GeoDatabase:
# Layer: UtilityNumber, Type: None
# Layer: BUILDINGRELATEBUILDINGNAME, Type: None
# Layer: SITENAME, Type: None
# Layer: SITERELATESITENAME, Type: None
# Layer: Street_Code, Type: None
# Layer: BUILDINGNAME, Type: None
# Layer: ADDRESSRELATEBUILDINGSITE, Type: None
# Layer: ADDRESS, Type: None
# Layer: BSLineAnno, Type: Multi Polygon
# Layer: BSPointAnno, Type: Multi Polygon
# Layer: BSPolygonAnno, Type: Multi Polygon
# Layer: Building, Type: 3D Multi Polygon
# Layer: BuildingAccessoryLine, Type: 3D Multi Line String
# Layer: BuildingAnno, Type: Multi Polygon
# Layer: BuildingAnnoHouseNo, Type: Multi Polygon
# Layer: BuiltStructureLine, Type: 3D Multi Line String
# Layer: BuiltStructurePoint, Type: 3D Point
# Layer: BuiltStructurePolygon, Type: 3D Multi Polygon
# Layer: CartoBuildingLine, Type: 3D Multi Line String
# Layer: ProposedInfraAnno, Type: Multi Polygon
# Layer: ProposedInfraStructureLine, Type: 3D Multi Line String
# Layer: ProposedInfraStructurePoint, Type: 3D Point
# Layer: Site, Type: 3D Multi Polygon
# Layer: SiteAnno, Type: Multi Polygon
# Layer: SubSite, Type: 3D Multi Polygon
# Layer: SubSiteAnno, Type: Multi Polygon
# Layer: CartoHydroLine, Type: 3D Multi Line String
# Layer: HydroLine, Type: 3D Multi Line String
# Layer: HydroLineAnno, Type: Multi Polygon
# Layer: HydroPoint, Type: 3D Point
# Layer: HydroPointAnno, Type: Multi Polygon
# Layer: HydroPolygon, Type: 3D Multi Polygon
# Layer: HydroPolygonAnno, Type: Multi Polygon
# Layer: Shoreline, Type: 3D Multi Line String
# Layer: BoulderPoint, Type: 3D Point
# Layer: BoulderPolygon, Type: 3D Multi Polygon
# Layer: CartoLandCoverLine, Type: 3D Multi Line String
# Layer: LandCoverAnno, Type: Multi Polygon
# Layer: LandCoverVector2, Type: 3D Multi Polygon
# Layer: Tree, Type: 3D Point
# Layer: PlaceNameAnno, Type: Multi Polygon
# Layer: Berm, Type: 3D Multi Polygon
# Layer: BMSslope, Type: 3D Multi Polygon
# Layer: BMSslopeAnno, Type: Multi Polygon
# Layer: CartoReliefLine, Type: 3D Multi Line String
# Layer: Contour, Type: 3D Multi Line String
# Layer: ContourAnno, Type: Multi Polygon
# Layer: SpotHeight, Type: 3D Point
# Layer: VerticalCutPolygon, Type: 3D Multi Polygon
# Layer: CartoPedLine, Type: 3D Measured Multi Line String
# Layer: CartoTransLine, Type: 3D Measured Multi Line String
# Layer: PedestrianAnno, Type: Multi Polygon
# Layer: RailwayAnno, Type: Multi Polygon
# Layer: RailwayEntrance, Type: 3D Measured Point
# Layer: RailwayPolygon, Type: 3D Measured Multi Polygon
# Layer: RoadAnno, Type: Multi Polygon
# Layer: RoadAssetPoint, Type: 3D Measured Point
# Layer: TerminalAnno, Type: Multi Polygon
# Layer: TransportLine, Type: 3D Measured Multi Line String
# Layer: TransportLineAnno, Type: Multi Polygon
# Layer: TransportPolygon, Type: 3D Measured Multi Polygon
# Layer: TransportPolygonAnno, Type: Multi Polygon
# Layer: StreetCentreLines, Type: 3D Measured Multi Line String
# Layer: CartoUtilityLine, Type: 3D Multi Line String
# Layer: UtilityLine, Type: 3D Multi Line String
# Layer: UtilityLineAnno, Type: Multi Polygon
# Layer: UtilityPoint, Type: 3D Point
# Layer: UtilityPointAnno, Type: Multi Polygon
# Layer: UtilityPolygon, Type: 3D Multi Polygon
# Layer: UtilityPolygonAnno, Type: Multi Polygon
# Layer: BMSslopeSymbol, Type: 3D Point

# %%
# Define the paths and layer name (comment out either one gdb_path when not in use)
#gdb_path = "data/iB1000.gdb"
gdb_path = r"C:\Users\Steve_Lau\Desktop\LS Training\ls_project1\iB1000.gdb"
csv_path1 = "data/BUILDINGNAME.csv"
layer_name1 = "BUILDINGNAME"
csv_path2 = "data/BUILDINGRELATEBUILDINGNAME.csv"
layer_name2 = "BUILDINGRELATEBUILDINGNAME"

# Convert from GDB to CSV by calling "converter" function
converter(gdb_path, csv_path1, layer_name1)
converter(gdb_path, csv_path2, layer_name2)
# Out:
# Conversion completed successfully
# Conversion completed successfully

# %%
# Read the CSV files into DataFrames
df1 = pd.read_csv(csv_path1)
df2 = pd.read_csv(csv_path2)

# Select only the "BUILDINGNAMEID", "ENGLISHBUILDINGNAME", and "CHINESEBUILDINGNAME" columns from df1
df1_subset = df1[["BUILDINGNAMEID", "ENGLISHBUILDINGNAME", "CHINESEBUILDINGNAME"]]

# Merge df2 with the subset of df1 on the "BUILDINGNAMEID" column
df3 = pd.merge(df2, df1_subset, on="BUILDINGNAMEID")

# Display the first few rows of the merged DataFrame
df3.head()
# Out:
#         LASTUPDATEDATE  BUILDINGNAMEID  BUILDINGID  \
# 0  2023/09/03 00:00:00      1101367973  1100000458
# 1  2023/09/03 00:00:00      1101367804  1100004056
# 2  2023/09/03 00:00:00      1101368243  1100011094
# 3  2023/09/03 00:00:00      1101367784  1100003706
# 4  2023/09/03 00:00:00      1101365720  1100002338
#
#              ENGLISHBUILDINGNAME CHINESEBUILDINGNAME
# 0  Chuen Lung Village Aqua Privy               川龍村旱廁
# 1                            NaN          木棉下村公所何氏家祠
# 2            Mount Haven Block 5              曉峰園第５座
# 3             Yi Pei Chun Toilet               二陂圳廁所
# 4          Lo Wai Village Office               老圍村公所

# %%
gdf1 = gpd.read_file(gdb_path, layer="Building")
gdf1.head()
# Out:
#   LASTUPDATEDATE  BUILDINGID TYPEOFBUILDINGBLOCK  BASELEVEL  ROOFLEVEL  \
# 0     2024-05-08  1910247820                   T        8.1  16.799999
# 1     2024-05-08  1910247815                   T        8.1  16.100000
# 2     2024-05-07  1910247774                  TS        NaN        NaN
# 3     2024-05-03  1910247696                  TS        7.2  10.300000
# 4     2024-05-03  1910247695                  TS        7.2  10.400000
#
#    BASELEVELDATASOURCE  ROOFLEVELDATASOURCE BUILDINGSTATUS  CERTAINTY  \
# 0                  4.0                  4.0              E          1
# 1                  4.0                  4.0              E          1
# 2                  NaN                  NaN              E          1
# 3                  4.0                  4.0              E          1
# 4                  4.0                  4.0              E          1
#
#    Shape_Length  Shape_Area                                           geometry
# 0     23.908286   31.450706  MULTIPOLYGON Z (((816145.174 831352.931 0.000,...
# 1     24.364307   31.712137  MULTIPOLYGON Z (((816134.845 831345.483 0.000,...
# 2     16.514416   15.452368  MULTIPOLYGON Z (((818016.014 838748.731 0.000,...
# 3     32.868446   53.716489  MULTIPOLYGON Z (((831625.175 840983.536 0.000,...
# 4    121.792729  226.482654  MULTIPOLYGON Z (((831631.172 840978.743 0.000,...

# %%
# Select only the "BUILDINGID", "ENGLISHBUILDINGNAME", and "CHINESEBUILDINGNAME" columns from df3
df3_subset = df3[["BUILDINGID", "ENGLISHBUILDINGNAME", "CHINESEBUILDINGNAME"]]

# Merge gdf1 with the subset of df3 on the "BUILDINGID" column
gdf2 = pd.merge(gdf1, df3_subset, on="BUILDINGID")

# Display the first few rows of the merged DataFrame
gdf2.head()
# Out:
#   LASTUPDATEDATE  BUILDINGID TYPEOFBUILDINGBLOCK  BASELEVEL  ROOFLEVEL  \
# 0     2024-05-08  1910247693                   T        5.3      120.0
# 1     2024-05-05  1910247673                   P        NaN        NaN
# 2     2024-05-05  1910247670                   P        NaN        NaN
# 3     2024-05-05  1910247669                   P        NaN        NaN
# 4     2024-05-05  1910247632                   T        NaN        NaN
#
#    BASELEVELDATASOURCE  ROOFLEVELDATASOURCE BUILDINGSTATUS  CERTAINTY  \
# 0                 10.0                 10.0              E          1
# 1                  NaN                  NaN              P          1
# 2                  NaN                  NaN              P          1
# 3                  NaN                  NaN              P          1
# 4                  NaN                  NaN              P          1
#
#    Shape_Length   Shape_Area  \
# 0    134.739147  1175.061936
# 1    576.375163  4219.597921
# 2    211.508289  1867.085492
# 3    267.948414  2513.780813
# 4    187.242046  1123.065147
#
#                                             geometry  \
# 0  MULTIPOLYGON Z (((834979.859 812118.914 0.000,...
# 1  MULTIPOLYGON Z (((838683.841 832108.401 0.000,...
# 2  MULTIPOLYGON Z (((838802.481 832136.004 0.000,...
# 3  MULTIPOLYGON Z (((838774.334 832051.217 0.000,...
# 4  MULTIPOLYGON Z (((838755.868 832088.787 0.000,...
#
#                    ENGLISHBUILDINGNAME CHINESEBUILDINGNAME
# 0                           Viva Place                 偉華匯
# 1                               Podium                  平台
# 2                               Podium                  平台
# 3                               Podium                  平台
# 4  RESIDENTIAL RECREATIONAL FACILITIES              住客康樂設施

# %%
#shp_path = "data/building.shp"

#Convert the datetimes to strings
#gdf2['LASTUPDATEDATE'] = gdf2['LASTUPDATEDATE'].dt.strftime('%Y-%m-%d')

#gdf2.to_file(shp_path, encoding='utf-8')
# Out:
# C:\Users\Steve_Lau\AppData\Local\Temp\ipykernel_26052\1715028947.py:6: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   gdf2.to_file(shp_path, encoding='utf-8')
